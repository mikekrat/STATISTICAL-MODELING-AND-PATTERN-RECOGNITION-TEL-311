# %%
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

def plot_some_data(train_images, train_labels, class_names):
    plt.figure(figsize=(10,10))
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(train_images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[train_labels[i]])
    plt.show()


def plot_some_predictions(test_images, test_labels, predictions, class_names, num_rows=5, num_cols=3):
    # Plot the first X test images, their predicted labels, and the true labels.
    # Color correct predictions in blue and incorrect predictions in red.   
    num_images = num_rows*num_cols
    plt.figure(figsize=(2*2*num_cols, 2*num_rows))
    for i in range(num_images):
        plt.subplot(num_rows, 2*num_cols, 2*i+1)
        plot_image(i, predictions[i], test_labels, class_names, test_images)
        plt.subplot(num_rows, 2*num_cols, 2*i+2)
        plot_value_array(i, predictions[i], test_labels)
    plt.tight_layout()
    plt.show() 




def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

def plot_image(i, predictions_array, true_label, class_names, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

# %% [markdown]
# model without batch norm and dropout

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

#from plots import plot_some_data, plot_some_predictions


fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Scale these values to a range of 0 to 1 before feeding them to the neural network model. 
# To do so, divide the values by 255. 
# It's important that the training set and the testing set be preprocessed in the same way
train_images = train_images / 255.0

test_images = test_images / 255.0

train_images_reshaped = train_images.reshape(-1,28,28,1)# reshape to mum_train_images X height X width X channels, where channels = 1
test_images_reshaped = test_images.reshape(-1,28,28,1)# reshape


# Build the model
# Building the neural network requires configuring the layers of the model, then compiling the model.

model = keras.Sequential()# fill the model

# 1st conv layer
model.add(layers.Conv2D(32, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (28, 28, 1)))

# 2nd conv layer
model.add(layers.Conv2D(32, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (28, 28, 1)))

# 1st max pool
model.add(layers.MaxPooling2D((2, 2), padding = 'valid'))

# 3rd conv layer
model.add(layers.Conv2D(64, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (14, 14, 32)))

# 4th conv layer
model.add(layers.Conv2D(64, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (14, 14, 64)))

# 2nd max pool
model.add(layers.MaxPooling2D((2, 2), padding = 'valid'))

# 5th conv layer
model.add(layers.Conv2D(128, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (7, 7, 64)))

# 3rd max pool
model.add(layers.MaxPooling2D((2, 2), padding = 'valid'))

#model.summary()

# flat layer
model.add(layers.Flatten())

# 1st dense layer
model.add(layers.Dense(200))

# 2nd dense layer
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Train the model
# Training the neural network model requires the following steps:

#   1. Feed the training data to the model. In this example, the training data is in the train_images and train_labels arrays.
#   2. The model learns to associate images and labels.
#   3. You ask the model to make predictions about a test set—in this example, the test_images array.
#   4. Verify that the predictions match the labels from the test_labels array.

history = model.fit(train_images_reshaped, train_labels, epochs=50, validation_data=(test_images_reshaped, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'], label = 'accurancy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.title('model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train_acc', 'test_acc'], loc='lower right')
plt.show()

# Evaluate accuracy
test_loss, test_acc = model.evaluate(test_images_reshaped,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)

# Make predictions
# With the model trained, you can use it to make predictions about some images. 
# The model's linear outputs, logits. 
# Attach a softmax layer to convert the logits to probabilities, which are easier to interpret. 
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

predictions = probability_model.predict(test_images_reshaped)

plot_some_predictions(test_images, test_labels, predictions, class_names, num_rows=5, num_cols=3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 200)               230600
#
#  dense_1 (Dense)             (None, 10)                2010
#
# =================================================================
# Total params: 371,458
# Trainable params: 371,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1875/1875 [==============================] - 20s 5ms/step - loss: 0.4054 - accuracy: 0.8573 - val_loss: 0.3610 - val_accuracy: 0.8714
# Epoch 2/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2920 - accuracy: 0.8972 - val_loss: 0.3201 - val_accuracy: 0.8848
# Epoch 3/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2552 - accuracy: 0.9084 - val_loss: 0.2863 - val_accuracy: 0.8956
# Epoch 4/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2297 - accuracy: 0.9179 - val_loss: 0.2818 - val_accuracy: 0.8985
# Epoch 5/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2087 - accuracy: 0.9251 - val_loss: 0.2914 - val_accuracy: 0.9028
# Epoch 6/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1969 - accuracy: 0.9285 - val_loss: 0.3038 - val_accuracy: 0.9020
# Epoch 7/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1744 - accuracy: 0.9369 - val_loss: 0.3300 - val_accuracy: 0.9010
# Epoch 8/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1599 - accuracy: 0.9418 - val_loss: 0.3215 - val_accuracy: 0.9042
# Epoch 9/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1531 - accuracy: 0.9449 - val_loss: 0.3805 - val_accuracy: 0.8935
# Epoch 10/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1408 - accuracy: 0.9496 - val_loss: 0.3419 - val_accuracy: 0.9025
# Epoch 11/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1332 - accuracy: 0.9526 - val_loss: 0.4265 - val_accuracy: 0.8942
# Epoch 12/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1289 - accuracy: 0.9540 - val_loss: 0.4053 - val_accuracy: 0.8995
# Epoch 13/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1172 - accuracy: 0.9588 - val_loss: 0.4399 - val_accuracy: 0.8974
# Epoch 14/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1168 - accuracy: 0.9597 - val_loss: 0.3843 - val_accuracy: 0.9015
# Epoch 15/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1113 - accuracy: 0.9612 - val_loss: 0.4586 - val_accuracy: 0.8971
# Epoch 16/50
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.1094 - accuracy: 0.9631 - val_loss: 0.4444 - val_accuracy: 0.8895
# Epoch 17/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1028 - accuracy: 0.9655 - val_loss: 0.4894 - val_accuracy: 0.8959
# Epoch 18/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1048 - accuracy: 0.9658 - val_loss: 0.4820 - val_accuracy: 0.9001
# Epoch 19/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0968 - accuracy: 0.9675 - val_loss: 0.5160 - val_accuracy: 0.8982
# Epoch 20/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1079 - accuracy: 0.9656 - val_loss: 0.5207 - val_accuracy: 0.8942
# Epoch 21/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0942 - accuracy: 0.9689 - val_loss: 0.5892 - val_accuracy: 0.8925
# Epoch 22/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0987 - accuracy: 0.9685 - val_loss: 0.6718 - val_accuracy: 0.8944
# Epoch 23/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0970 - accuracy: 0.9702 - val_loss: 0.6246 - val_accuracy: 0.8848
# Epoch 24/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0930 - accuracy: 0.9709 - val_loss: 0.7110 - val_accuracy: 0.8956
# Epoch 25/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0978 - accuracy: 0.9703 - val_loss: 0.6588 - val_accuracy: 0.8927
# Epoch 26/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0941 - accuracy: 0.9720 - val_loss: 0.6573 - val_accuracy: 0.8932
# Epoch 27/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0997 - accuracy: 0.9702 - val_loss: 0.7825 - val_accuracy: 0.8824
# Epoch 28/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0940 - accuracy: 0.9725 - val_loss: 0.6767 - val_accuracy: 0.8994
# Epoch 29/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1012 - accuracy: 0.9711 - val_loss: 0.6826 - val_accuracy: 0.8897
# Epoch 30/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0970 - accuracy: 0.9724 - val_loss: 0.6886 - val_accuracy: 0.8922
# Epoch 31/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0991 - accuracy: 0.9718 - val_loss: 0.7295 - val_accuracy: 0.8949
# Epoch 32/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0932 - accuracy: 0.9733 - val_loss: 0.8303 - val_accuracy: 0.8882
# Epoch 33/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0941 - accuracy: 0.9736 - val_loss: 0.8760 - val_accuracy: 0.8839
# Epoch 34/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0987 - accuracy: 0.9727 - val_loss: 0.7799 - val_accuracy: 0.8917
# Epoch 35/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0988 - accuracy: 0.9740 - val_loss: 0.7692 - val_accuracy: 0.8946
# Epoch 36/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0917 - accuracy: 0.9757 - val_loss: 0.9040 - val_accuracy: 0.8958
# Epoch 37/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1080 - accuracy: 0.9733 - val_loss: 0.9514 - val_accuracy: 0.8917
# Epoch 38/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0975 - accuracy: 0.9748 - val_loss: 0.8788 - val_accuracy: 0.8891
# Epoch 39/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1048 - accuracy: 0.9738 - val_loss: 0.8237 - val_accuracy: 0.8975
# Epoch 40/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1039 - accuracy: 0.9748 - val_loss: 0.8974 - val_accuracy: 0.8954
# Epoch 41/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0992 - accuracy: 0.9758 - val_loss: 0.9778 - val_accuracy: 0.8967
# Epoch 42/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1035 - accuracy: 0.9755 - val_loss: 1.0689 - val_accuracy: 0.8941
# Epoch 43/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1015 - accuracy: 0.9761 - val_loss: 1.0840 - val_accuracy: 0.8852
# Epoch 44/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1147 - accuracy: 0.9740 - val_loss: 1.0131 - val_accuracy: 0.8966
# Epoch 45/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1046 - accuracy: 0.9762 - val_loss: 1.1307 - val_accuracy: 0.8943
# Epoch 46/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1090 - accuracy: 0.9757 - val_loss: 1.0216 - val_accuracy: 0.8922
# Epoch 47/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1134 - accuracy: 0.9748 - val_loss: 1.0867 - val_accuracy: 0.8933
# Epoch 48/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1069 - accuracy: 0.9765 - val_loss: 0.9962 - val_accuracy: 0.8959
# Epoch 49/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1193 - accuracy: 0.9749 - val_loss: 1.1147 - val_accuracy: 0.8983
# Epoch 50/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1240 - accuracy: 0.9763 - val_loss: 1.1958 - val_accuracy: 0.8958
# 313/313 - 1s - loss: 1.1958 - accuracy: 0.8958 - 778ms/epoch - 2ms/step
#
# Test accuracy: 0.895799994468689

# %% [markdown]
# model without dropout

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

#from plots import plot_some_data, plot_some_predictions


fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Scale these values to a range of 0 to 1 before feeding them to the neural network model. 
# To do so, divide the values by 255. 
# It's important that the training set and the testing set be preprocessed in the same way
train_images = train_images / 255.0

test_images = test_images / 255.0

train_images_reshaped = train_images.reshape(-1,28,28,1)# reshape to mum_train_images X height X width X channels, where channels = 1
test_images_reshaped = test_images.reshape(-1,28,28,1)# reshape


# Build the model
# Building the neural network requires configuring the layers of the model, then compiling the model.

model = keras.Sequential()# fill the model

# 1st conv layer
model.add(layers.Conv2D(32, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (28, 28, 1)))

# 1st batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 2nd conv layer
model.add(layers.Conv2D(32, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (28, 28, 1)))

# 2nd batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 1st max pool
model.add(layers.MaxPooling2D((2, 2), padding = 'valid'))

# 3rd conv layer
model.add(layers.Conv2D(64, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (14, 14, 32)))

# 3rd batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 4th conv layer
model.add(layers.Conv2D(64, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (14, 14, 64)))

# 4th batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 2nd max pool
model.add(layers.MaxPooling2D((2, 2), padding = 'valid'))

# 5th conv layer
model.add(layers.Conv2D(128, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (7, 7, 64)))

# 5th batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 3rd max pool
model.add(layers.MaxPooling2D((2, 2), padding = 'valid'))

#model.summary()

# flat layer
model.add(layers.Flatten())

# 1st dense layer
model.add(layers.Dense(200))

# 6th batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 2nd dense layer
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Train the model
# Training the neural network model requires the following steps:

#   1. Feed the training data to the model. In this example, the training data is in the train_images and train_labels arrays.
#   2. The model learns to associate images and labels.
#   3. You ask the model to make predictions about a test set—in this example, the test_images array.
#   4. Verify that the predictions match the labels from the test_labels array.

history = model.fit(train_images_reshaped, train_labels, epochs=50, validation_data=(test_images_reshaped, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'], label = 'accurancy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.title('model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train_acc', 'test_acc'], loc='lower right')
plt.show()

# Evaluate accuracy
test_loss, test_acc = model.evaluate(test_images_reshaped,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)

# Make predictions
# With the model trained, you can use it to make predictions about some images. 
# The model's linear outputs, logits. 
# Attach a softmax layer to convert the logits to probabilities, which are easier to interpret. 
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

predictions = probability_model.predict(test_images_reshaped)

plot_some_predictions(test_images, test_labels, predictions, class_names, num_rows=5, num_cols=3)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 28, 28, 32)        320
#
#  batch_normalization_6 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  activation_6 (Activation)   (None, 28, 28, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 32)        9248
#
#  batch_normalization_7 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  activation_7 (Activation)   (None, 28, 28, 32)        0
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 64)        18496
#
#  batch_normalization_8 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  activation_8 (Activation)   (None, 14, 14, 64)        0
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 64)        36928
#
#  batch_normalization_9 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  activation_9 (Activation)   (None, 14, 14, 64)        0
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 128)         73856
#
#  batch_normalization_10 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  activation_10 (Activation)  (None, 7, 7, 128)         0
#
#  max_pooling2d_8 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 200)               230600
#
#  batch_normalization_11 (Bat  (None, 200)              800
#  chNormalization)
#
#  activation_11 (Activation)  (None, 200)               0
#
#  dense_5 (Dense)             (None, 10)                2010
#
# =================================================================
# Total params: 373,538
# Trainable params: 372,498
# Non-trainable params: 1,040
# _________________________________________________________________
# Epoch 1/50
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.3345 - accuracy: 0.8770 - val_loss: 0.2833 - val_accuracy: 0.8960
# Epoch 2/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2266 - accuracy: 0.9176 - val_loss: 0.2476 - val_accuracy: 0.9094
# Epoch 3/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1878 - accuracy: 0.9312 - val_loss: 0.2466 - val_accuracy: 0.9137
# Epoch 4/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1614 - accuracy: 0.9402 - val_loss: 0.2296 - val_accuracy: 0.9196
# Epoch 5/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1363 - accuracy: 0.9493 - val_loss: 0.2376 - val_accuracy: 0.9211
# Epoch 6/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1156 - accuracy: 0.9560 - val_loss: 0.2058 - val_accuracy: 0.9289
# Epoch 7/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0955 - accuracy: 0.9650 - val_loss: 0.2695 - val_accuracy: 0.9181
# Epoch 8/50
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0802 - accuracy: 0.9700 - val_loss: 0.2327 - val_accuracy: 0.9277
# Epoch 9/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0661 - accuracy: 0.9758 - val_loss: 0.2438 - val_accuracy: 0.9314
# Epoch 10/50
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0555 - accuracy: 0.9794 - val_loss: 0.2762 - val_accuracy: 0.9242
# Epoch 11/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0476 - accuracy: 0.9825 - val_loss: 0.2744 - val_accuracy: 0.9263
# Epoch 12/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0425 - accuracy: 0.9850 - val_loss: 0.2744 - val_accuracy: 0.9308
# Epoch 13/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0379 - accuracy: 0.9863 - val_loss: 0.3329 - val_accuracy: 0.9244
# Epoch 14/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0342 - accuracy: 0.9873 - val_loss: 0.3208 - val_accuracy: 0.9267
# Epoch 15/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0303 - accuracy: 0.9888 - val_loss: 0.3345 - val_accuracy: 0.9250
# Epoch 16/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0278 - accuracy: 0.9896 - val_loss: 0.3679 - val_accuracy: 0.9254
# Epoch 17/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0257 - accuracy: 0.9908 - val_loss: 0.3247 - val_accuracy: 0.9328
# Epoch 18/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0250 - accuracy: 0.9910 - val_loss: 0.3487 - val_accuracy: 0.9282
# Epoch 19/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0214 - accuracy: 0.9926 - val_loss: 0.3475 - val_accuracy: 0.9301
# Epoch 20/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0232 - accuracy: 0.9919 - val_loss: 0.3843 - val_accuracy: 0.9231
# Epoch 21/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0190 - accuracy: 0.9933 - val_loss: 0.3892 - val_accuracy: 0.9289
# Epoch 22/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0209 - accuracy: 0.9924 - val_loss: 0.3561 - val_accuracy: 0.9284
# Epoch 23/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 0.3795 - val_accuracy: 0.9297
# Epoch 24/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0169 - accuracy: 0.9941 - val_loss: 0.3938 - val_accuracy: 0.9275
# Epoch 25/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0161 - accuracy: 0.9941 - val_loss: 0.3958 - val_accuracy: 0.9276
# Epoch 26/50
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0171 - accuracy: 0.9938 - val_loss: 0.3780 - val_accuracy: 0.9299
# Epoch 27/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0161 - accuracy: 0.9946 - val_loss: 0.4243 - val_accuracy: 0.9270
# Epoch 28/50
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.3728 - val_accuracy: 0.9330
# Epoch 29/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.3878 - val_accuracy: 0.9314
# Epoch 30/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.4118 - val_accuracy: 0.9307
# Epoch 31/50
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0146 - accuracy: 0.9945 - val_loss: 0.4320 - val_accuracy: 0.9248
# Epoch 32/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0130 - accuracy: 0.9952 - val_loss: 0.4419 - val_accuracy: 0.9260
# Epoch 33/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.3914 - val_accuracy: 0.9306
# Epoch 34/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.4308 - val_accuracy: 0.9311
# Epoch 35/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.4029 - val_accuracy: 0.9333
# Epoch 36/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.4411 - val_accuracy: 0.9280
# Epoch 37/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.4391 - val_accuracy: 0.9297
# Epoch 38/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.4082 - val_accuracy: 0.9319
# Epoch 39/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.4538 - val_accuracy: 0.9254
# Epoch 40/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.4191 - val_accuracy: 0.9326
# Epoch 41/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.4627 - val_accuracy: 0.9274
# Epoch 42/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.4233 - val_accuracy: 0.9326
# Epoch 43/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.4510 - val_accuracy: 0.9318
# Epoch 44/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.4679 - val_accuracy: 0.9292
# Epoch 45/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.4615 - val_accuracy: 0.9317
# Epoch 46/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.4836 - val_accuracy: 0.9296
# Epoch 47/50
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.4692 - val_accuracy: 0.9287
# Epoch 48/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.4370 - val_accuracy: 0.9330
# Epoch 49/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.4847 - val_accuracy: 0.9300
# Epoch 50/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.4288 - val_accuracy: 0.9346
# 313/313 - 1s - loss: 0.4288 - accuracy: 0.9346 - 862ms/epoch - 3ms/step
#
# Test accuracy: 0.9345999956130981

# %% [markdown]
# final model

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

#from plots import plot_some_data, plot_some_predictions


fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Scale these values to a range of 0 to 1 before feeding them to the neural network model. 
# To do so, divide the values by 255. 
# It's important that the training set and the testing set be preprocessed in the same way
train_images = train_images / 255.0

test_images = test_images / 255.0

train_images_reshaped = train_images.reshape(-1,28,28,1)# reshape to mum_train_images X height X width X channels, where channels = 1
test_images_reshaped = test_images.reshape(-1,28,28,1)# reshape


# Build the model
# Building the neural network requires configuring the layers of the model, then compiling the model.

model = keras.Sequential()# fill the model

# 1st conv layer
model.add(layers.Conv2D(32, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (28, 28, 1)))

# 1st batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 2nd conv layer
model.add(layers.Conv2D(32, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (28, 28, 1)))

# 2nd batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 1st max pool
model.add(layers.MaxPooling2D((2, 2), padding = 'valid'))
model.add(layers.Dropout(0.2))

# 3rd conv layer
model.add(layers.Conv2D(64, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (14, 14, 32)))

# 3rd batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 4th conv layer
model.add(layers.Conv2D(64, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (14, 14, 64)))

# 4th batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 2nd max pool
model.add(layers.MaxPooling2D((2, 2), padding = 'valid'))
model.add(layers.Dropout(0.3))

# 5th conv layer
model.add(layers.Conv2D(128, (3, 3), strides = 1, padding = 'same', activation = None, input_shape = (7, 7, 64)))

# 5th batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

# 3rd max pool
model.add(layers.MaxPooling2D((2, 2), padding = 'valid'))
model.add(layers.Dropout(0.4))

#model.summary()

# flat layer
model.add(layers.Flatten())

# 1st dense layer
model.add(layers.Dense(200))

# 6th batch norm
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))

model.add(layers.Dropout(0.5))

# 2nd dense layer
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Train the model
# Training the neural network model requires the following steps:

#   1. Feed the training data to the model. In this example, the training data is in the train_images and train_labels arrays.
#   2. The model learns to associate images and labels.
#   3. You ask the model to make predictions about a test set—in this example, the test_images array.
#   4. Verify that the predictions match the labels from the test_labels array.

history = model.fit(train_images_reshaped, train_labels, epochs=50, validation_data=(test_images_reshaped, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'], label = 'accurancy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.title('model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train_acc', 'test_acc'], loc='lower right')
plt.show()

# Evaluate accuracy
test_loss, test_acc = model.evaluate(test_images_reshaped,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)

# Make predictions
# With the model trained, you can use it to make predictions about some images. 
# The model's linear outputs, logits. 
# Attach a softmax layer to convert the logits to probabilities, which are easier to interpret. 
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

predictions = probability_model.predict(test_images_reshaped)

plot_some_predictions(test_images, test_labels, predictions, class_names, num_rows=5, num_cols=3)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 28, 28, 32)        320
#
#  batch_normalization_12 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  activation_12 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 32)        9248
#
#  batch_normalization_13 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  activation_13 (Activation)  (None, 28, 28, 32)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 64)        18496
#
#  batch_normalization_14 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  activation_14 (Activation)  (None, 14, 14, 64)        0
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 64)        36928
#
#  batch_normalization_15 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  activation_15 (Activation)  (None, 14, 14, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  conv2d_19 (Conv2D)          (None, 7, 7, 128)         73856
#
#  batch_normalization_16 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  activation_16 (Activation)  (None, 7, 7, 128)         0
#
#  max_pooling2d_11 (MaxPoolin  (None, 3, 3, 128)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten_3 (Flatten)         (None, 1152)              0
#
#  dense_6 (Dense)             (None, 200)               230600
#
#  batch_normalization_17 (Bat  (None, 200)              800
#  chNormalization)
#
#  activation_17 (Activation)  (None, 200)               0
#
#  dropout_3 (Dropout)         (None, 200)               0
#
#  dense_7 (Dense)             (None, 10)                2010
#
# =================================================================
# Total params: 373,538
# Trainable params: 372,498
# Non-trainable params: 1,040
# _________________________________________________________________
# Epoch 1/50
# 1875/1875 [==============================] - 13s 6ms/step - loss: 0.5468 - accuracy: 0.8036 - val_loss: 0.3507 - val_accuracy: 0.8719
# Epoch 2/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3520 - accuracy: 0.8735 - val_loss: 0.2815 - val_accuracy: 0.8973
# Epoch 3/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3045 - accuracy: 0.8891 - val_loss: 0.2994 - val_accuracy: 0.8899
# Epoch 4/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2841 - accuracy: 0.8978 - val_loss: 0.2313 - val_accuracy: 0.9128
# Epoch 5/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2661 - accuracy: 0.9042 - val_loss: 0.2321 - val_accuracy: 0.9149
# Epoch 6/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2543 - accuracy: 0.9089 - val_loss: 0.2070 - val_accuracy: 0.9238
# Epoch 7/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2420 - accuracy: 0.9128 - val_loss: 0.2065 - val_accuracy: 0.9262
# Epoch 8/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2317 - accuracy: 0.9171 - val_loss: 0.2051 - val_accuracy: 0.9243
# Epoch 9/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2270 - accuracy: 0.9175 - val_loss: 0.2016 - val_accuracy: 0.9289
# Epoch 10/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2168 - accuracy: 0.9217 - val_loss: 0.2022 - val_accuracy: 0.9242
# Epoch 11/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2099 - accuracy: 0.9231 - val_loss: 0.1885 - val_accuracy: 0.9331
# Epoch 12/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2094 - accuracy: 0.9244 - val_loss: 0.1887 - val_accuracy: 0.9305
# Epoch 13/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2038 - accuracy: 0.9272 - val_loss: 0.2051 - val_accuracy: 0.9241
# Epoch 14/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1972 - accuracy: 0.9286 - val_loss: 0.1780 - val_accuracy: 0.9339
# Epoch 15/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1921 - accuracy: 0.9311 - val_loss: 0.1815 - val_accuracy: 0.9332
# Epoch 16/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1914 - accuracy: 0.9310 - val_loss: 0.1763 - val_accuracy: 0.9347
# Epoch 17/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1861 - accuracy: 0.9329 - val_loss: 0.1800 - val_accuracy: 0.9358
# Epoch 18/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1823 - accuracy: 0.9335 - val_loss: 0.1782 - val_accuracy: 0.9355
# Epoch 19/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1787 - accuracy: 0.9346 - val_loss: 0.1735 - val_accuracy: 0.9369
# Epoch 20/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1751 - accuracy: 0.9364 - val_loss: 0.1811 - val_accuracy: 0.9331
# Epoch 21/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1720 - accuracy: 0.9359 - val_loss: 0.1721 - val_accuracy: 0.9349
# Epoch 22/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1732 - accuracy: 0.9381 - val_loss: 0.1744 - val_accuracy: 0.9341
# Epoch 23/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1685 - accuracy: 0.9392 - val_loss: 0.1738 - val_accuracy: 0.9368
# Epoch 24/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1652 - accuracy: 0.9404 - val_loss: 0.1727 - val_accuracy: 0.9365
# Epoch 25/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1633 - accuracy: 0.9400 - val_loss: 0.1799 - val_accuracy: 0.9359
# Epoch 26/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1642 - accuracy: 0.9403 - val_loss: 0.1765 - val_accuracy: 0.9361
# Epoch 27/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1599 - accuracy: 0.9419 - val_loss: 0.1702 - val_accuracy: 0.9395
# Epoch 28/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1548 - accuracy: 0.9430 - val_loss: 0.1723 - val_accuracy: 0.9358
# Epoch 29/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1576 - accuracy: 0.9427 - val_loss: 0.1649 - val_accuracy: 0.9397
# Epoch 30/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1555 - accuracy: 0.9430 - val_loss: 0.1827 - val_accuracy: 0.9330
# Epoch 31/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1535 - accuracy: 0.9442 - val_loss: 0.1685 - val_accuracy: 0.9383
# Epoch 32/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1508 - accuracy: 0.9442 - val_loss: 0.1768 - val_accuracy: 0.9353
# Epoch 33/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1500 - accuracy: 0.9457 - val_loss: 0.1659 - val_accuracy: 0.9393
# Epoch 34/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1482 - accuracy: 0.9461 - val_loss: 0.1735 - val_accuracy: 0.9348
# Epoch 35/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1492 - accuracy: 0.9452 - val_loss: 0.1638 - val_accuracy: 0.9413
# Epoch 36/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1442 - accuracy: 0.9469 - val_loss: 0.1677 - val_accuracy: 0.9414
# Epoch 37/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1434 - accuracy: 0.9476 - val_loss: 0.1670 - val_accuracy: 0.9375
# Epoch 38/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1429 - accuracy: 0.9472 - val_loss: 0.1651 - val_accuracy: 0.9396
# Epoch 39/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1414 - accuracy: 0.9480 - val_loss: 0.1644 - val_accuracy: 0.9415
# Epoch 40/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1417 - accuracy: 0.9484 - val_loss: 0.1650 - val_accuracy: 0.9387
# Epoch 41/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1391 - accuracy: 0.9487 - val_loss: 0.1625 - val_accuracy: 0.9402
# Epoch 42/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1392 - accuracy: 0.9485 - val_loss: 0.1640 - val_accuracy: 0.9409
# Epoch 43/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1382 - accuracy: 0.9491 - val_loss: 0.1637 - val_accuracy: 0.9423
# Epoch 44/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1366 - accuracy: 0.9501 - val_loss: 0.1638 - val_accuracy: 0.9413
# Epoch 45/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1336 - accuracy: 0.9521 - val_loss: 0.1626 - val_accuracy: 0.9411
# Epoch 46/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1344 - accuracy: 0.9516 - val_loss: 0.1659 - val_accuracy: 0.9400
# Epoch 47/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1343 - accuracy: 0.9518 - val_loss: 0.1675 - val_accuracy: 0.9362
# Epoch 48/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1315 - accuracy: 0.9520 - val_loss: 0.1686 - val_accuracy: 0.9384
# Epoch 49/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1296 - accuracy: 0.9520 - val_loss: 0.1611 - val_accuracy: 0.9424
# Epoch 50/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1315 - accuracy: 0.9514 - val_loss: 0.1616 - val_accuracy: 0.9397
# 313/313 - 1s - loss: 0.1616 - accuracy: 0.9397 - 748ms/epoch - 2ms/step
#
# Test accuracy: 0.9397000074386597
